# %% [markdown]
# ### The data

# %%
import pandas as pd
import numpy as np
# %pylab inline
import scipy.linalg as la
import seaborn as sbn
matplotlib.rcParams['figure.figsize'] =(14,8)

import metadata
reload(metadata)

import linreg
reload(linreg)

# Note that if we want to look at CV, we should use Y with positive values only (so no log)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'linreg' from 'linreg.pyc'>

# %%
inhibitor = 'mTOR'
df = pd.read_json(open('../data/inhibitors/%s_zscores_inh.json' % inhibitor,'r').read())
df
# Out:
#             CCK81  COLO320HSR      DIFI    HCT116     HT115      HT29  \
# AKT      0.146137    1.045266  1.397986  0.110741  2.090141  1.130861
# EGFR    -0.336677    0.261377  0.690798 -1.272318 -0.981494  0.018575
# ERK     -0.524057    0.591901 -2.200002 -3.627363  0.045039 -0.343416
# GSK3    -0.563257   -0.002395 -0.599088  0.727275 -1.983209 -1.252982
# IkBa    -0.564370    0.403079 -2.201574 -2.518986 -0.322574 -0.494797
# JNK     -0.403600    0.386699 -1.539781 -0.001780 -0.528578 -0.172662
# MEK      4.816603    1.197227  7.028946  3.652903  5.197917  2.447897
# PI3Kp85 -0.318351    0.042883 -2.072371 -1.445756 -1.743800 -0.404316
# RPS6    -0.689828    0.557424 -4.912399 -5.497628 -1.465715 -2.906459
# RSKp90  -0.618895    0.404239 -0.635683 -1.612660 -1.379436 -1.062050
# SMAD2   -0.334692    0.842736 -1.128410 -1.885783 -0.273824  0.982190
# cJun    -1.196555    0.774534 -0.530520 -1.018431 -1.123734 -0.134628
# mTOR    -0.516704    0.011971 -0.972318 -0.100036 -0.872046 -0.999615
# p38     -0.364654    0.366418 -1.843220 -2.429498 -0.443287  0.060572
#
#             SKCO1    SNUC2B     SNUC5    SW1116    SW1463     SW620     SW837
# AKT      1.984451  5.891085  9.120397  1.482342 -0.408961  0.056028 -1.057073
# EGFR    -0.546167 -0.456651  2.940168  1.399949 -1.051637 -1.166057 -0.211953
# ERK      0.082472 -0.311088  0.876871  0.334252 -1.299155 -0.833465 -1.457227
# GSK3     0.204411  0.448235  2.445939  0.892726 -1.009976 -0.142543 -0.684864
# IkBa     1.061726  0.518490  1.366151  0.564103 -1.322909 -1.667753 -1.282870
# JNK      0.709626 -0.480354  0.755924  1.470544 -1.045624 -1.127431 -0.092286
# MEK      4.084945  5.824997  7.488370  7.891407  5.654953  7.302621 -1.815334
# PI3Kp85 -0.318351 -0.901486  1.005532  1.365925 -0.927772 -1.223981 -0.562358
# RPS6    -0.348533  0.458047  5.809550 -1.733882 -1.428433 -3.465363 -1.670944
# RSKp90  -0.541269 -0.791120  2.259835  0.065704 -1.322068 -1.220816 -0.545053
# SMAD2    0.821398 -0.040526  1.218566  1.064693 -0.914357 -0.558423 -1.037985
# cJun     1.092636  0.596184  1.025251  1.060125 -1.502076  0.079100 -0.955196
# mTOR    -0.097236 -0.243510  1.904079  0.778434 -1.003946  0.348409 -3.927405
# p38      0.200060  0.926536  1.373091  1.051433 -0.573166 -1.023586 -0.159133

# %% [markdown]
# ### Read the IC50

# %%
IC50 = pd.read_json('../data/IC50.json')
IC50 = IC50[IC50.columns[1:]].ix[inhibitor]  # drop CAR1 for now because input json are buggy
# !!!!!!!!!!!!!!!!!!!!!
# fill NA with zeros for now otherwise beta estimate fails
IC50 = IC50.fillna(2)
Y = IC50.values
Y = np.exp(IC50.values) # to express in micro mol ?
Y
# Out:
# array([ 1.42831239,  0.71999445,  1.27867639,  1.10624226,  1.96678285,
#         1.80571383,  1.28596616,  2.37857333,  2.2546706 ,  7.3890561 ,
#         7.3890561 ,  3.37650742,  7.3890561 ])

# %%
TFs =  ['GSK3', 'IkBa',  'ERK', 'RPS6', 'RSKp90', 'SMAD2', 'cJun', 'p38', 'mTOR'] 
TFs =  ['IkBa',  'ERK', 'RPS6', 'RSKp90', 'cJun', 'p38', 'mTOR'] 

X = df.ix[TFs].as_matrix()
X.shape
X = X.transpose()

# %%
p = X.shape[1] # len(X.columns) 
N = X.shape[0] # len(df)

# %% [markdown]
# ### Estimate beta

# %%
beta = linreg.estimate_beta(X, Y)

#beta1 = linreg.ridge_estimate(X, Y)
#beta, beta1
#beta = linreg.ridge_estimate(X, Y)
beta
# Out:
# array([-3.3150111 , -1.86254027, -0.22209084, -0.81215588, -0.09703491,
#         6.62307557,  0.11004531])

# %% [markdown]
# ### Fix Y and perturb X: effect on beta estimation

# %%
#if X is full rank, it an be inverted and OLS can be used
# this is true if singular values are non-zero (diagonal of D)
U,D,V = la.svd(X, full_matrices = False) # We call full_matrices = False, to conform with the conventions in the text
D
# Out:
# array([ 13.75582045,   4.44377867,   3.58661197,   2.28864464,
#          1.7676148 ,   1.13099563,   0.88194596])

# %%
errors = []
for i in range(0,10000):
    beta_hat = linreg.estimate_beta(X, Y, noise_level=0.01)
    #beta_hat = linreg.ridge_estimate(X, Y, L=3, noise_level=0.05)
    errors.append(beta_hat)

# %%
# Let us look at the systematic bias and variation (sigma)
_ = pd.DataFrame(errors).hist(bins=100)
axes = gcf().get_axes()
for i in range(0, len(beta)):
    axes[i].axvline(beta[i], color='r', lw=2)

# %%
df_errors = pd.DataFrame(errors)

# %%
_ = df_errors.boxplot()

# %% [markdown]
# ### Coefficient variation of beta_hat

# %%
(df_errors.std()/df_errors.mean()).plot(kind='bar')

# %% [markdown]
# ### Fix beta perturb X: effect on Y

# %%
beta = linreg.estimate_beta(X,Y)
beta
# Out:
# array([-3.3150111 , -1.86254027, -0.22209084, -0.81215588, -0.09703491,
#         6.62307557,  0.11004531])

# %%
def predict(X, beta, noise_level=0):
    this = linreg.linear_model(X+np.random.randn(N,p)*noise_level, beta)
    return this

# %%
yerrors = []
for i in range(0,10000):
    y = predict(X, beta, noise_level=0.01) #0.1 leads to CV of 0.06
    yerrors.append(y)
yerrors = pd.DataFrame(yerrors)

# %%
_ = yerrors.hist(bins=100)
axes = gcf().get_axes()
for i in range(0, len(Y)):
    axes[i].axvline(Y[i], color='r')

# %%
_ = yerrors.boxplot()

# %%
# !!!!!!!!!!!!!!!!!!!!!!1
# CV cannot be used here because Y values are pos and neg
abs((yerrors.std()/yerrors.mean())).plot(kind='bar')

# %%
# Here all errors seems equal probably becase Y is linked to X with same level of noise on each row.
yerrors.std()
# Out:
# 0     0.077924
# 1     0.076504
# 2     0.076801
# 3     0.076388
# 4     0.076899
# 5     0.078240
# 6     0.077398
# 7     0.076257
# 8     0.076110
# 9     0.076442
# 10    0.076663
# 11    0.076703
# 12    0.077611
# dtype: float64

# %%
(abs(yerrors-Y)/Y*100).mean().plot(kind='bar')
