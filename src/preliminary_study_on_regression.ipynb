# %% [markdown]
# ### The data

# %%
import pandas as pd
import numpy as np
# %pylab inline
import scipy.linalg as la
import seaborn as sbn
matplotlib.rcParams['figure.figsize'] =(14,8)

import metadata
reload(metadata)

import linreg
reload(linreg)

# Note that if we want to look at CV, we should use Y with positive values only (so no log)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# WARNING: pylab import has clobbered these variables: ['beta']
# `%matplotlib` prevents importing * from pylab and numpy
# <module 'linreg' from 'linreg.py'>

# %%
cell = 'DIFI'
df = pd.read_json(open('%s_zscores.json' % cell,'r').read())
df
# Out:
#             AKT       EGFR       ERK      GSK3      IkBa       JNK       MEK  \
# IKK   -0.790549  -2.221762 -1.036346 -1.370466 -0.615642 -0.573901  3.045695
# MEKi   0.683106 -11.359808 -0.474282 -2.113829 -0.084786 -1.539781  4.189906
# PI3K -10.247467  -1.068974 -2.066846 -1.668943 -2.011962 -1.607512 -1.561849
# PLX    2.459925  -1.928129 -2.001923 -2.142005 -1.343338 -0.990276  5.315718
# TAK  -10.340835  -3.476061 -2.001923 -1.617044 -1.717445 -1.894770  2.191798
# TBK1  -1.602643  -1.133983 -1.296556 -1.784366 -1.194664 -0.880667 -1.715813
# mTOR   1.397986   0.690798 -2.200002 -0.599088 -2.201574 -1.539781  7.028946
#
#        PI3Kp85      RPS6    RSKp90     SMAD2      cJun      mTOR       p38
# IKK  -0.717994 -2.820842 -0.449395 -0.913395 -0.913079 -0.678504 -1.393960
# MEKi -1.065321 -7.850436 -0.568678 -0.037423  0.703070 -1.478587 -2.146732
# PI3K -2.186630 -7.257914 -1.209657 -1.772101 -0.459515 -1.478587 -2.146732
# PLX  -1.852180 -9.117620 -0.503648 -3.104612 -4.210481 -1.959198 -1.843220
# TAK  -1.852180 -7.294576 -1.147507 -1.584818  0.511656 -1.185743 -2.146732
# TBK1 -0.717994 -2.106783 -0.196499 -0.811388 -1.404340 -1.060809 -1.393960
# mTOR -2.072371 -4.912399 -0.635683 -1.128410 -0.530520 -0.972318 -1.843220

# %% [markdown]
# ### Read the IC50

# %%
IC50 = pd.read_json('IC50.json')
IC50 = IC50[cell]
# !!!!!!!!!!!!!!!!!!!!!
# fill NA with zeros for now otherwise beta estimate fails
IC50 = IC50.fillna(2)
Y = IC50.values
Y = np.exp(IC50.values) # to express in micro mol ?
Y
# Out:
# array([   7.3890561 ,    5.05531127,   61.18853773,  148.98182052,
#           2.99308856,   10.45428701,    1.27867639])

# %%
TFs =  ['GSK3', 'IkBa',  'ERK', 'RPS6', 'RSKp90', 'SMAD2', 'cJun', 'p38', 'mTOR'] 

X = df[TFs].as_matrix()
X.shape
# Out:
# (7, 9)

# %%
p = 9 # len(X.columns) 
N = 7 # len(df)

# %% [markdown]
# ### Estimate beta

# %%
beta = linreg.estimate_beta(X, Y)

#beta1 = linreg.ridge_estimate(X, Y)
#beta, beta1
beta = linreg.ridge_estimate(X, Y)

# %% [markdown]
# ### Fix Y and perturb X: effect on beta estimation

# %%
#if X is full rank, it an be inverted and OLS can be used
# this is true if singular values are non-zero (diagonal of D)
U,D,V = la.svd(X, full_matrices = False) # We call full_matrices = False, to conform with the conventions in the text
D
# Out:
# array([ 19.78310803,   4.37220124,   2.92471412,   1.79767565,
#          0.81162659,   0.378711  ,   0.21214881])

# %%
errors = []
for i in range(0,10000):
    #beta_hat = linreg.estimate_beta(X, Y, noise_level=0.05)
    beta_hat = linreg.ridge_estimate(X, Y, L=3, noise_level=0.05)
    errors.append(beta_hat)

# %%
# Let us look at the systematic bias and variation (sigma)
_ = pd.DataFrame(errors).hist(bins=100)
axes = gcf().get_axes()
for i,ax in enumerate(axes):
    ax.axvline(beta[i], color='r', lw=2)

# %%
df_errors = pd.DataFrame(errors)

# %%
_ = df_errors.boxplot()

# %% [markdown]
# ### Coefficient variation of beta_hat

# %%
(df_errors.std()/df_errors.mean()).plot(kind='bar')

# %% [markdown]
# ### Fix beta perturb X: effect on Y

# %%
def predict(X, beta, noise_level=0):
    this = linear_model(X+np.random.randn(N,p)*noise_level, beta)
    return this

# %%
yerrors = []
for i in range(0,10000):
    y = predict(X, beta, noise_level=0.1) #0.1 leads to CV of 0.06
    yerrors.append(y)
yerrors = pd.DataFrame(yerrors)

# %%
_ = yerrors.hist(bins=100)
axes = gcf().get_axes()
for i,ax in enumerate(axes[0:-2]):
    ax.axvline(Y[i], color='r')

# %%
_ = yerrors.boxplot()

# %%
# !!!!!!!!!!!!!!!!!!!!!!1
# CV cannot be used here because Y values are pos and neg
abs((yerrors.std()/yerrors.mean())).plot(kind='bar')

# %%
# Here all errors seems equal probably becase Y is linked to X with same level of noise on each row.
yerrors.std()
# Out:
# 0    13.424254
# 1    13.355019
# 2    13.222369
# 3    13.408410
# 4    13.280189
# 5    13.391630
# 6    13.334702
# dtype: float64

# %%
Y
# Out:
# array([   7.3890561 ,    5.05531127,   61.18853773,  148.98182052,
#           2.99308856,   10.45428701,    1.27867639])

# %%
IC50
# Out:
# IKK     0.000000
# MEK     1.620439
# PI3K    4.113960
# PLX     5.003824
# TAK     1.096306
# TBK1    2.347012
# mTOR    0.245825
# Name: DIFI, dtype: float64
