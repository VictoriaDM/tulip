# %% [markdown]
# # Preliminary studies on predicting the IC50 of drugs from colon rectal phospho data sets

# %%
import pandas as pd
import numpy as np
# %pylab inline
import scipy.linalg as la
import seaborn as sbn
matplotlib.rcParams['figure.figsize'] =(14,8)

import metadata
reload(metadata)

import linreg
reload(linreg)

# Note that if we want to look at CV, we should use Y with positive values only (so no log)
# Out:
# Populating the interactive namespace from numpy and matplotlib
# <module 'linreg' from 'linreg.pyc'>

# %% [markdown]
# ### The data

# %% [markdown]
# We have phosphorylations from perturbation data sets for 14 cell lines. In each case, we have 46 perturbations but only 7 where
# stimuli are off and where there is 1 inhibitor. We will use that sub set of 7 inhibitors. For each of these combo of cell line
# and inhibitors, we have 14 measured proteins, some of them are Transcription Factors (TF).
#
#
# In the files data/inhibitors/<name>_zscores_inh.json, we have stored for each cell line and protein, the fold change as a zscore. Here below is an example of such file.

# %%
inhibitor = 'MEKi'
df = pd.read_json(open('../data/inhibitors/%s_zscores_inh.json' % inhibitor,'r').read())
inhibitor = 'MEK'  # note that for MEK, there is an i in the filename but no in the header...
df['one'] = [1] * 14
df
# Out:
#                  AKT       EGFR       ERK      GSK3      IkBa       JNK  \
# CAR1       -0.416836  -1.417401 -0.746742 -2.617421 -1.333770 -2.658259
# CCK81       2.239676  -0.092872  0.983117 -0.636962  0.189995 -0.340146
# COLO320HSR  1.133272   0.364870  0.341642 -0.943446 -0.016679 -0.206172
# DIFI        0.683106 -11.359808 -0.474282 -2.113829 -0.084786 -1.539781
# HCT116     -2.368707  -1.553293 -4.587514 -0.088283 -3.174516 -2.117668
# HT115      -0.531591  -0.914612  0.558082 -1.538083  0.812070 -0.627404
# HT29       -0.092313   0.223427 -0.226161 -2.340442  1.285485 -0.092286
# SKCO1       0.679132  -0.786006  1.090802 -0.204846  2.538270  0.619651
# SNUC2B      0.490860  -1.259513 -1.126643  0.044784  0.518490 -0.781999
# SNUC5       0.918288  -0.224355 -1.186241  1.098232 -0.437874 -0.795945
# SW1116     -0.083511   0.688452  1.381501  1.575730  1.123777  1.217123
# SW1463     -1.429113  -1.163787 -0.707400 -1.781164  0.656410 -1.251199
# SW620       0.076261  -0.692519  1.012590  1.261277 -0.602986 -1.949833
# SW837      -0.054055   1.015283  0.939716  1.010066  0.013624  1.334169
#
#                  MEK   PI3Kp85      RPS6    RSKp90     SMAD2      cJun  \
# CAR1        4.891507 -2.643294 -6.845343 -1.593784 -0.939674 -5.757526
# CCK81       8.994653 -0.060395  0.326480  1.236426 -0.589119  0.234311
# COLO320HSR  1.487572 -0.318351 -0.446179  0.032857  0.537422  0.658016
# DIFI        4.189906 -1.065321 -7.850436 -0.568678 -0.037423  0.703070
# HCT116      2.470506 -4.222098 -9.858227 -1.771735 -2.321569 -6.066970
# HT115       1.034218 -0.920981 -2.418707  0.800635 -0.567611 -2.203101
# HT29        0.558253  0.241500 -1.019118 -0.537698  0.254289 -0.977214
# SKCO1       3.438138  0.521531  0.733752  0.098870  1.186037  0.909321
# SNUC2B      1.942455 -1.394304 -1.001803 -1.200850 -0.270327 -0.020179
# SNUC5       3.772253 -0.318351 -1.595382  0.677448 -0.771534 -1.035275
# SW1116      9.904990  1.059840 -1.197901  1.192689  0.595287  0.568187
# SW1463      4.505007 -1.208174  0.328017 -0.347295 -0.518454 -1.238892
# SW620       5.323728 -1.223981 -5.245050  0.220732 -1.027078  0.442452
# SW837       2.748138  0.239520  1.890066  0.078347  0.573351 -0.383228
#
#                 mTOR       p38  one
# CAR1       -0.460405 -2.217764    1
# CCK81       0.094325 -0.206714    1
# COLO320HSR -0.133885 -0.165560    1
# DIFI       -1.478587 -2.146732    1
# HCT116     -0.985565 -3.292975    1
# HT115      -1.784097 -0.523911    1
# HT29       -0.332774  0.060572    1
# SKCO1       0.069706  0.317293    1
# SNUC2B     -1.060123  0.265315    1
# SNUC5      -0.276821 -0.522594    1
# SW1116      1.236833  0.796540    1
# SW1463     -0.797446 -0.573166    1
# SW620       0.867194 -1.212071    1
# SW837      -1.547557  0.331754    1

# %% [markdown]
# ### The IC50

# %% [markdown]
# We have extracted the IC50 for the inhibitors found in our data sets and for each cell line

# %%
# we can look at the IC50 as an image. grey boxes represent the NAs
# If we look at each row, mTOR is stable but others are no (e.g., MEK, IKK)
IC50 = pd.read_json('../data/IC50.json')
try:
    from biokit import imshow
    imshow(IC50)
except:
    imshow(IC50)

# %% [markdown]
# For the prediction, we want to predict an IC50 for a given inhibitor given as measurements
# made on **p** TFs. We have **N=14** cell line and can only assumes that they can be used as different $\bf{X}$ input to the regression problem. So The $\bf{Y}$ vector to be predicted has the length equal to the number of cell lines. $\bf{X}$ has dimension $N \times p$

# %% [markdown]
# **---------------!!!!!!!!!!!!!!!!!!!!!!--------------**
#
# HEre we have 2 issues:
# * NAs need to be taken care of. How ? For now we replace with zeros
# * IC50 are in log scale, do we want real measurements in micro mol ? If so need to take the exp

# %% [markdown]
# ### Get Y vector

# %%
IC50 = pd.read_json('../data/IC50.json')
IC50 = IC50.ix[inhibitor]  
# !!!!!!!!!!!!!!!!!!!!!
# fill NA with zeros for now otherwise beta estimate fails
IC50 = IC50.fillna(0)
Y = IC50.values
#Y = np.exp(IC50.values) # to express in micro mol ?
Y
# Out:
# array([ 2.74384029,  3.84591869,  3.44858291,  1.62043943, -0.09063774,
#         1.85930261, -1.87055005, -0.25613462,  1.81333696,  0.81332325,
#         0.47667078,  0.62478925, -0.8073207 , -0.05242934])

# %% [markdown]
# ### Get X matrix

# %% [markdown]
# We select some measurents believed to be transcription factor

# %%
TFs =  ['one', 'GSK3', 'IkBa',  'ERK', 'RPS6', 'RSKp90', 'SMAD2', 'cJun', 'p38', 'mTOR'] 
TFs =  ['one',  'ERK',  'RSKp90', 'cJun', 'mTOR'] 
#TFs = ['mTOR', 'AKT']
X = df[TFs].as_matrix()
X.shape
#X = X.transpose()
X
# Out:
# array([[ 1.        , -0.74674158, -1.59378369, -5.75752619, -0.46040471],
#        [ 1.        ,  0.98311743,  1.2364261 ,  0.23431068,  0.09432543],
#        [ 1.        ,  0.34164195,  0.03285689,  0.65801583, -0.13388482],
#        [ 1.        , -0.47428222, -0.56867787,  0.70307012, -1.47858694],
#        [ 1.        , -4.5875137 , -1.77173458, -6.06696969, -0.98556519],
#        [ 1.        ,  0.55808213,  0.80063506, -2.20310076, -1.78409743],
#        [ 1.        , -0.22616085, -0.53769757, -0.97721389, -0.33277359],
#        [ 1.        ,  1.09080221,  0.09887019,  0.90932075,  0.06970615],
#        [ 1.        , -1.12664271, -1.20085024, -0.02017864, -1.06012348],
#        [ 1.        , -1.18624055,  0.67744766, -1.0352751 , -0.27682057],
#        [ 1.        ,  1.38150126,  1.19268936,  0.56818663,  1.23683286],
#        [ 1.        , -0.70739969, -0.34729507, -1.23889187, -0.79744587],
#        [ 1.        ,  1.01258954,  0.22073232,  0.44245198,  0.86719355],
#        [ 1.        ,  0.93971649,  0.07834722, -0.38322833, -1.54755672]])

# %%
p = X.shape[1] # len(X.columns) 
N = X.shape[0] # len(df)

# %% [markdown]
# ### Estimate beta

# %%
beta = linreg.estimate_beta(X, Y)

#beta1 = linreg.ridge_estimate(X, Y)
#beta, beta1
#beta = linreg.ridge_estimate(X, Y)
beta
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %% [markdown]
# ### Fix Y and perturb X: effect on beta estimation

# %%
#if X is full rank, it an be inverted and OLS can be used
# this is true if singular values are non-zero (diagonal of D)
U,D,V = la.svd(X, full_matrices = False) # We call full_matrices = False, to conform with the conventions in the text
D
# Out:
# array([ 10.51970503,   4.30457569,   3.50569124,   2.39401013,   2.0662627 ])

# %%
errors = []
for i in range(0,10000):
    beta_hat = linreg.estimate_beta(X, Y, noise_level=0.1)
    #beta_hat = linreg.ridge_estimate(X, Y, L=3, noise_level=0.05)
    errors.append(beta_hat)

# %%
# Let us look at the systematic bias and variation (sigma)
_ = pd.DataFrame(errors).hist(bins=100)
axes = gcf().get_axes()
for i in range(0, len(beta)):
    axes[i].axvline(beta[i], color='r', lw=2)

# %%
df_errors = pd.DataFrame(errors)

# %%
_ = df_errors.boxplot()
# Out:
# /home/cokelaer/Work/virtualenv/lib/python2.7/site-packages/pandas/tools/plotting.py:2625: FutureWarning:
# The default value for 'return_type' will change to 'axes' in a future release.
#  To use the future behavior now, set return_type='axes'.
#  To keep the previous behavior and silence this warning, set return_type='dict'.
#   warnings.warn(msg, FutureWarning)

# %% [markdown]
# ### Coefficient variation of beta_hat

# %%
(df_errors.std()/df_errors.mean()).plot(kind='bar')

# %% [markdown]
# **For a noise of sigma=0.1, CV are 25% Note however, that we should notuse CV with negative values...**

# %% [markdown]
# ### Fix beta perturb X: effect on Y

# %%
beta = linreg.estimate_beta(X,Y)
beta
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
#using scikit learn, we get same results using fit_intercept=False
#reg = LinReg(fit_intercept=False)
#eg.fit(X, Y)
#from sklearn.linear_model import Ridge, Lasso, Lars
#reg = Lars()
#reg.fit(X, Y)

def predict(X, beta, noise_level=0):
    this = linreg.linear_model(X+np.random.randn(N,p)*noise_level, beta)
    #this = reg.predict(X + np.random.randn(N,p)*noise_level)
    return this

# %%
yerrors = []
for i in range(0,10000):
    y = predict(X, beta, noise_level=0.1) #0.1 leads to CV of 0.06
    yerrors.append(y)
yerrors = pd.DataFrame(yerrors)

# %%
_ = yerrors.hist(bins=100)
axes = gcf().get_axes()
for i in range(0, len(Y)):
    axes[i].axvline(Y[i], color='r')

# %% [markdown]
# **Here we have tremendous biases!!! ** Irrespecteive of the inhibitor chosen

# %%
_ = yerrors.boxplot()

# %%
# !!!!!!!!!!!!!!!!!!!!!!1
# CV cannot be used here because Y values are pos and neg
abs((yerrors.std()/yerrors.mean())).plot(kind='bar')

# %%
# Here all errors seems equal probably becase Y is linked to X with same level of noise on each row.
yerrors.std()
# Out:
# 0     0.097297
# 1     0.098241
# 2     0.098270
# 3     0.097227
# 4     0.096987
# 5     0.097349
# 6     0.096642
# 7     0.096953
# 8     0.097568
# 9     0.096224
# 10    0.097385
# 11    0.098117
# 12    0.096521
# 13    0.097177
# dtype: float64

# %%
(abs(yerrors-Y)/Y*100).mean().plot(kind='bar')

# %% [markdown]
# ### Check with scikit learn

# %%
beta
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
X
# Out:
# array([[ 1.        , -0.74674158, -1.59378369, -5.75752619, -0.46040471],
#        [ 1.        ,  0.98311743,  1.2364261 ,  0.23431068,  0.09432543],
#        [ 1.        ,  0.34164195,  0.03285689,  0.65801583, -0.13388482],
#        [ 1.        , -0.47428222, -0.56867787,  0.70307012, -1.47858694],
#        [ 1.        , -4.5875137 , -1.77173458, -6.06696969, -0.98556519],
#        [ 1.        ,  0.55808213,  0.80063506, -2.20310076, -1.78409743],
#        [ 1.        , -0.22616085, -0.53769757, -0.97721389, -0.33277359],
#        [ 1.        ,  1.09080221,  0.09887019,  0.90932075,  0.06970615],
#        [ 1.        , -1.12664271, -1.20085024, -0.02017864, -1.06012348],
#        [ 1.        , -1.18624055,  0.67744766, -1.0352751 , -0.27682057],
#        [ 1.        ,  1.38150126,  1.19268936,  0.56818663,  1.23683286],
#        [ 1.        , -0.70739969, -0.34729507, -1.23889187, -0.79744587],
#        [ 1.        ,  1.01258954,  0.22073232,  0.44245198,  0.86719355],
#        [ 1.        ,  0.93971649,  0.07834722, -0.38322833, -1.54755672]])

# %%
from sklearn.linear_model import LinearRegression as LinReg

# %%
reg = LinReg(fit_intercept=False)

# %%
reg.fit(X, Y)
# Out:
# LinearRegression(copy_X=True, fit_intercept=False, normalize=False)

# %%
reg.coef_
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
Xp = X +np.random.randn(N,p)*0
reg.predict(Xp)
# Out:
# array([ 1.02793682,  1.30924197,  0.79146585,  0.95425904,  0.61943966,
#         2.14150498,  0.79371409,  0.8175259 ,  0.55694869,  1.08698448,
#         0.86745421,  1.00638263,  0.6080365 ,  1.5882369 ])

# %%
Y
# Out:
# array([ 2.74384029,  3.84591869,  3.44858291,  1.62043943, -0.09063774,
#         1.85930261, -1.87055005, -0.25613462,  1.81333696,  0.81332325,
#         0.47667078,  0.62478925, -0.8073207 , -0.05242934])

# %%
beta
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
reg.score(Xp, Y)
# Out:
# 0.068627787134922347

# %%
beta, reg.coef_
# Out:
# (array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022]),
#  array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022]))

# %%
# contribution of a given beta to errors ?
i = 2
plot(beta[0]*0 + X[:,i] * beta[i], Y, 'o', label=TFs[1])
xr = linspace(0,1,14); plot(xr, beta[0] + xr * beta[i], 'r-')

print X
# Out:
# [[ 2.29193916  0.45735322  1.11681624 -0.41234285 -1.15311702]
#  [ 3.212509    0.64105163  1.56539156 -0.57796259 -1.61627275]
#  [ 2.88061307  0.57482227  1.4036653  -0.51825119 -1.44928977]
#  [ 1.35355858  0.2701007   0.6595621  -0.24351877 -0.68100038]
#  [-0.07571001 -0.01510783 -0.03689198  0.01362099  0.03809111]
#  [ 1.55308181  0.30991528  0.75678579 -0.279415   -0.78138422]
#  [-1.56247684 -0.31179005 -0.7613638   0.28110526  0.78611102]
#  [-0.21395012 -0.04269344 -0.10425363  0.03849177  0.10764227]
#  [ 1.51468655  0.30225356  0.73807654 -0.2725073  -0.76206684]
#  [ 0.67937168  0.13556766  0.33104427 -0.12222578 -0.34180447]
#  [ 0.39816473  0.07945321  0.19401773 -0.07163383 -0.20032405]
#  [ 0.52188859  0.10414213  0.2543059  -0.09389299 -0.26257181]
#  [-0.67435774 -0.13456713 -0.32860108  0.12132372  0.33928186]
#  [-0.0437944  -0.00873911 -0.02134014  0.00787905  0.02203378]]

# %% [markdown]
# ### Can we predict anything

# %% [markdown]
# Let us now create X from beta and X. In which case, we should have a perfect fit

# %%
beta
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
p = 5
beta2 = np.array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
# values close to 0 leads to larger CV because all stadanrd variation will be 
# mixed errors on Y equal. So we start at 1 instead of 0 but the effect can be seen anyway (see figures below)
#N = 100
#Y = linspace(1, 10, N)
#Y2 = np.array([ 1.52276357,  1.42831239,  0.71999445,  1.27867639,  1.10624226,
#        1.96678285,  1.80571383,  1.28596616,  2.37857333,  2.2546706 ,
#        7.3890561 ,  7.3890561 ,  3.37650742,  7.3890561 ])

# %% [markdown]
# ### Here, we compute X given Y and beta

# %%
X
# Out:
# matrix([[ 2.29193916,  0.45735322,  1.11681624, -0.41234285, -1.15311702],
#         [ 3.212509  ,  0.64105163,  1.56539156, -0.57796259, -1.61627275],
#         [ 2.88061307,  0.57482227,  1.4036653 , -0.51825119, -1.44928977],
#         [ 1.35355858,  0.2701007 ,  0.6595621 , -0.24351877, -0.68100038],
#         [-0.07571001, -0.01510783, -0.03689198,  0.01362099,  0.03809111],
#         [ 1.55308181,  0.30991528,  0.75678579, -0.279415  , -0.78138422],
#         [-1.56247684, -0.31179005, -0.7613638 ,  0.28110526,  0.78611102],
#         [-0.21395012, -0.04269344, -0.10425363,  0.03849177,  0.10764227],
#         [ 1.51468655,  0.30225356,  0.73807654, -0.2725073 , -0.76206684],
#         [ 0.67937168,  0.13556766,  0.33104427, -0.12222578, -0.34180447],
#         [ 0.39816473,  0.07945321,  0.19401773, -0.07163383, -0.20032405],
#         [ 0.52188859,  0.10414213,  0.2543059 , -0.09389299, -0.26257181],
#         [-0.67435774, -0.13456713, -0.32860108,  0.12132372,  0.33928186],
#         [-0.0437944 , -0.00873911, -0.02134014,  0.00787905,  0.02203378]])

# %%
def getX(Y, beta):
    betaprime = la.pinv(np.dot(np.matrix(beta), np.matrix(beta).T))
    betaprime = np.dot(np.matrix(beta).T, betaprime)
    # Y should be transformed here but numpy artifact ?
    X = np.dot(np.matrix(Y).T, betaprime.T)
    return X

# %%
X = getX(Y, beta)
X = X
imshow(X, aspect='auto', cmap='jet');

# %%
# Now, we perturb X and compute Y. The idea is to estimate the propagation of the errors from X to Y if
# we know beta very well
yerrors = []
for i in range(0,10000):
    y = predict(X, beta, noise_level=1) #0.1 leads to CV of 0.06
    yerrors.append(np.array(y)[0])
    
yerrors = pd.DataFrame(yerrors)

# %%
X.max()
# Out:
# 3.2125089953063366

# %%
X.shape
# Out:
# (14, 5)

# %%
beta
# Out:
# array([ 0.76606249,  0.15286669,  0.37328697, -0.13782233, -0.38542022])

# %%
#i=13; hist(yerrors[i],100); axvline(Y[i], lw=2, color='r')
_ = yerrors.hist(bins=100)
axes = gcf().get_axes()
for i in range(0, len(Y)):
    axes[i].axvline(Y[i], color='r')

# %%
(abs(yerrors-Y)/abs(Y)*100).mean().plot(kind='bar')
ylim([-100,100])
ylabel("Error in Y")

# %%
def get_score(y):
    r1 = ((Y-y)**2).sum()
    r2 = ((y-Y.mean() )**2).sum()
    return 1-r1/r2

# %%
scores = [get_score(this[1].values) for this in yerrors.iterrows()]
hist(scores)
# Out:
# (array([  1.00000000e+00,   0.00000000e+00,   0.00000000e+00,
#           1.00000000e+00,   2.00000000e+00,   6.00000000e+00,
#           6.80000000e+01,   7.14000000e+02,   5.51700000e+03,
#           3.69100000e+03]),
#  array([-3.48118034, -3.06064089, -2.64010145, -2.219562  , -1.79902255,
#         -1.37848311, -0.95794366, -0.53740421, -0.11686476,  0.30367468,
#          0.72421413]),
#  <a list of 10 Patch objects>)
