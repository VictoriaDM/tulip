# %% [markdown]
# ### The data

# %%
import pandas as pd
import numpy as np
# %pylab inline
import scipy.linalg as la
import seaborn as sbn
matplotlib.rcParams['figure.figsize'] =(14,8)
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %%
df = pd.read_json(open('DIFI.json','r').read())
df
# Out:
#         AKT      EGFR       ERK      GSK3      IkBa       JNK       MEK  \
# 0  0.000002  0.499984  0.488238  0.498584  0.490963  0.499026  0.499270
# 1  0.500241  0.500000  0.478478  0.500000  0.478330  0.499366  0.999900
# 2  0.500000  0.000001  0.500000  0.485360  0.500000  0.499366  0.982899
# 3  0.499055  0.499970  0.499886  0.497245  0.499950  0.499998  0.498134
# 4  0.499999  0.476357  0.499988  0.499802  0.500000  0.500000  0.768860
# 5  0.560403  0.494058  0.491396  0.483356  0.499838  0.499992  0.998366
# 6  0.000002  0.093253  0.491396  0.498967  0.498117  0.495000  0.520765
#
#        PI3K      RPS6    RSKp90     SMAD2      cJun      mTOR       p38
# 0  0.479699  0.000073  0.499943  0.497427  0.500000  0.499577  0.482998
# 1  0.487927  0.003582  0.500000  0.499972  0.500000  0.499994  0.496196
# 2  0.499984  0.000033  0.500000  0.500000  0.500000  0.499577  0.482998
# 3  0.500000  0.485827  0.500000  0.499999  0.499748  0.499985  0.499766
# 4  0.500000  0.324628  0.500000  0.499997  0.499997  0.500000  0.499766
# 5  0.496009  0.000007  0.500000  0.207569  0.016310  0.493042  0.496196
# 6  0.496009  0.000069  0.499966  0.499155  0.500000  0.499953  0.482998

# %%
X = df.as_matrix()

# %%
p = 14 # len(X.columns) 
N = 7 # len(df)

# %% [markdown]
# ### The model

# %%
def linear_model(X, beta):
    import numpy as np
    return np.dot(X, beta)

# %% [markdown]
# ### The estimation

# %%
def ols(X):
    """
    The matrix which solves the OLS regression problem for full-rank X
    """
    return np.dot(la.pinv(np.dot(X.T, X)), X.T)

# %%
# We don't have beta or Y for now, so let us fake values for beta
beta = [random.uniform(0.3,0.7) for i in range(0,14)]
Y = linear_model(X, beta)
Y, beta
# Out:
# (array([ 3.05956664,  3.52859348,  3.31958848,  3.59049659,  3.63048671,
#          3.09858418,  2.91497921]),
#  [0.3342218313972647,
#   0.41741217039510664,
#   0.30492952640254517,
#   0.32654628054240026,
#   0.5213094662090123,
#   0.6320390813222165,
#   0.5888256671698504,
#   0.5591749169323055,
#   0.6882167648354356,
#   0.46149506505985394,
#   0.5056635219281067,
#   0.6333244934521964,
#   0.6782365793324916,
#   0.554485775241828])

# %%
noise_level = 0.01
beta_hat = np.dot(ols(X + np.random.randn(N,p)*noise_level), Y)

def estimate_beta(X, Y, noise_level=0):
    beta_hat = np.dot(ols(X + np.random.randn(N,p)*noise_level), Y)
    return beta_hat

# %%
plot(beta, beta_hat, 'or')
xlabel(r'$\beta$', fontsize=20)
ylabel(r'$\hat{\beta}$', fontsize=20)
m = min([min(beta), min(beta_hat)])
M = max([max(beta), max(beta_hat)])
plot([m,M], [m,M], '-')

# %%
errors = []
for i in range(0,10000):
    beta_hat = estimate_beta(X, Y, noise_level=0.05)
    errors.append(beta_hat)

# %%
# Let us look at the systematic bias and variation (sigma)
_ = pd.DataFrame(errors).hist(bins=100)
axes = gcf().get_axes()
for i,ax in enumerate(axes[0:-2]):
    ax.axvline(beta[i], color='r')

# %%
df_errors = pd.DataFrame(errors)

# %%
_ = df_errors.boxplot()

# %% [markdown]
# ### Coefficient variation of beta_hat

# %%
(df_errors.std()/df_errors.mean()).plot(kind='bar')

# %% [markdown]
# ### Effect on Y of noisy X

# %%
def predict(X, beta, noise_level=0):
    this = linear_model(X+np.random.randn(N,p)*noise_level, beta)
    return this

# %%
yerrors = []
for i in range(0,10000):
    y = predict(X, beta, noise_level=0.2) #0.1 leads to CV of 0.06
    yerrors.append(y)
yerrors = pd.DataFrame(yerrors)

# %%
_ = yerrors.hist(bins=100)
axes = gcf().get_axes()
for i,ax in enumerate(axes[0:-2]):
    ax.axvline(Y[i], color='r')

# %%
_ = yerrors.boxplot()

# %%
(yerrors.std()/yerrors.mean()).plot(kind='bar')
